# %%
import torch
from src.dvst.config.provider import DVSTConfigProvider
from src.dvst.datasets.provider import DVSTDatasetProvider

config_provider = DVSTConfigProvider()
config = config_provider.get_default_config()

dataset_provider = DVSTDatasetProvider()
dataset = dataset_provider.create_train_dataset(config.train.data.dataset)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
s = dataset[0]
s.view_datas[0].t
s.__dict__.keys(), s.view_datas[0].__dict__.keys()
# Out:
# (dict_keys(['scene_id', 'view_datas', 'n_frames', 'sources_idx', 'queries_targets_idx']),
#  dict_keys(['K', 'R', 't', 'time', 'fps', 'shape', 'resize_to', 'view']))

# %%
s = dataset[0]
t = torch.stack([d.t for d in s.view_datas]).squeeze()
t.max(0).values, t.min(0).values
# Out:
# (tensor([-0.0124, -0.3073, -0.0209]), tensor([-0.0160, -0.4396, -0.0431]))

# %%
import sunds

builder = sunds.builder('kubric:kubric/msn_ms_v4.3a')
builder.frame_builder.info
# Out:
# 2025-10-20 13:15:30.760282: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-20 13:15:34.403950: W external/local_xla/xla/tsl/platform/cloud/google_auth_provider.cc:185] All attempts to get a Google authentication bearer token failed, returning an empty token. Retrieving token from files failed with "NOT_FOUND: Could not locate the credentials file.". Retrieving token from GCE failed with "FAILED_PRECONDITION: Error executing an HTTP request: libcurl code 6 meaning 'Could not resolve hostname', error details: Could not resolve host: metadata.google.internal".
# tfds.core.DatasetInfo(
#     name='kubric_frames',
#     full_name='kubric_frames/msn_ms_v4.3a/2.9.1',
#     description="""
#
#     """,
#     config_description="""
# ...
